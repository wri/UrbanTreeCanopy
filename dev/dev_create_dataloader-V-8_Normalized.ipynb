# %% [markdown]
# ### Purpose: Create a dataloader
#
# ###### Date:11/13/2019

# %%
# Import libraries
from __future__ import print_function, division
import os
from skimage import io, transform
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
from torch.utils.data import DataLoader, Dataset

print(torch.__version__)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()   # interactive mode
# Out:
# 1.3.0

# %% [markdown]
# ### Check the data catalog

# %%
data_root='/datadrive/UTC/'
place = 'Santa_Monica'
data_path=data_root+place+'/'

catalog_path = data_root+'data_catalog.csv'

# convert band_means & band_stds from string to list of array
def to_array(x):
    if isinstance(x,str):
        x = eval(x)
    return np.array(x)

converter = {'band_means':to_array,'band_stds':to_array} 
data_catalog = pd.read_csv(catalog_path,converters = converter) 

data_catalog.head()
# Out:
#                                          raster_path  \
# 0  /datadrive/UTC/Santa_Monica/combiTif/Santa_Mon...
# 1  /datadrive/UTC/Santa_Monica/combiTif/Santa_Mon...
# 2  /datadrive/UTC/Santa_Monica/combiTif/Santa_Mon...
# 3  /datadrive/UTC/Santa_Monica/combiTif/Santa_Mon...
# 4  /datadrive/UTC/Santa_Monica/combiTif/Santa_Mon...
#
#                                         imagery_path  \
# 0  /datadrive/UTC/Santa_Monica/NAIP/imagery/none/...
# 1  /datadrive/UTC/Santa_Monica/NAIP/imagery/none/...
# 2  /datadrive/UTC/Santa_Monica/NAIP/imagery/none/...
# 3  /datadrive/UTC/Santa_Monica/NAIP/imagery/none/...
# 4  /datadrive/UTC/Santa_Monica/NAIP/imagery/none/...
#
#                                          binary_path         place  tileID  \
# 0  /datadrive/UTC/Santa_Monica/fullMasks/binary/S...  Santa_Monica       0
# 1  /datadrive/UTC/Santa_Monica/fullMasks/binary/S...  Santa_Monica       1
# 2  /datadrive/UTC/Santa_Monica/fullMasks/binary/S...  Santa_Monica       2
# 3  /datadrive/UTC/Santa_Monica/fullMasks/binary/S...  Santa_Monica       3
# 4  /datadrive/UTC/Santa_Monica/fullMasks/binary/S...  Santa_Monica       4
#
#   suffix  img_size  res  pad       lat  ...  img_src  \
# 0      A       256    1    0  359712.0  ...    naip1
# 1      A       256    1    0  359712.0  ...    naip1
# 2      A       256    1    0  359968.0  ...    naip1
# 3      A       256    1    0  359968.0  ...    naip1
# 4      A       256    1    0  359968.0  ...    naip1
#
#                               lidar_src  \
# 0  USGS_LPC_CA_LosAngeles_2016_LAS_2018
# 1  USGS_LPC_CA_LosAngeles_2016_LAS_2018
# 2  USGS_LPC_CA_LosAngeles_2016_LAS_2018
# 3  USGS_LPC_CA_LosAngeles_2016_LAS_2018
# 4  USGS_LPC_CA_LosAngeles_2016_LAS_2018
#
#                                           band_means  \
# 0  [18.891204833984375, 18.5040283203125, 17.6068...
# 1  [1.288421630859375, 1.2667694091796875, 1.2102...
# 2  [13.987213134765625, 13.629104614257812, 13.28...
# 3  [153.93601989746094, 150.54244995117188, 145.7...
# 4  [82.99894714355469, 83.22972106933594, 83.4470...
#
#                                            band_stds ndvi_mean  ndvi_std  \
# 0  [57.29494771343193, 56.12163180997879, 53.4039... -0.094515  0.006674
# 1  [15.699684914668946, 15.430954788947341, 14.73... -0.092167  0.028384
# 2  [48.43713477757454, 47.19827194378038, 46.0044... -0.055390  0.009834
# 3  [68.06969366741113, 66.21124215271861, 63.1174... -0.075629  0.040046
# 4  [74.19453890950487, 73.54065359071565, 72.8486... -0.027280  0.144895
#
#    ndvi_NaN  height_mean  height_std  height_NaN
# 0     59109     0.129057    0.209841         592
# 1     65095     0.347044    1.274629           6
# 2     60489    -0.036909    0.300037           0
# 3      9569     0.269359    1.552605           0
# 4     24177     5.150508    9.644906           0
#
# [5 rows x 21 columns]

# %%
# check a sample to ensure correct conversion from string to array
data_catalog.sample().band_means.iloc[0]
# Out:
# array([102.04322815, 102.96192932, 101.25491333, 103.69377136])

# %%
# find the mean of band_means and band_stds 

means = np.array(data_catalog.band_means).mean()

stdevs = np.array(data_catalog.band_stds).mean()

means,stdevs
# Out:
# (array([93.3878109 , 93.93750004, 91.96530171, 94.08799182]),
#  array([43.40660275, 40.68388145, 39.20582527, 40.8151277 ]))

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# ### Create a dataloader using image_kit

# %%
import image_kit.handler as hd
import image_kit.io as io

# %%
# setting input parameters

height_threshold = 4
ndvi_threshold = 0.1
EPS = 1e-8
DEFAULT_BATCH_SIZE =16

# %%
# create a dataset class for our Urban Tree Canopy dataset
# set band_indices to None because ndvi, height already calculated in raster_path

class UrbanTreeDataset(Dataset):
    """Urban Tree Canopy dataset."""
    @classmethod
    def loader(cls,
            dataframe,
            batch_size=DEFAULT_BATCH_SIZE,
            partial_batches=False,
            loader_kwargs={},
            **kwargs):
        r""" convenience method for loading the DataLoader directly.
            
            Args:
                see class args

            Returns:
                dataloader 
        """


        return DataLoader(cls(dataframe,**kwargs),batch_size=batch_size,**loader_kwargs)
    
    def __init__(self,
            dataframe,     
            means=None,
            stdevs=None,
            band_indices=['ndvi'],
            augment=False,
#             value_map=vmap,
#             train_mode=True,
#             target_expand_axis=None,
#             UPDATE_VERSION=update_version,
#             shuffle_data=shuffle
                ):
        self.handler=hd.InputTargetHandler(
            means=means,
            stdevs=stdevs,
            band_indices=band_indices,
            augment=augment,
            target_squeeze=False,
            target_dtype = np.float
        )
        
        self.canopy_frame = pd.read_csv(dataframe)
        
    def __len__(self):
        return len(self.canopy_frame)         
    
    def __getitem__(self, index):
        
        self.select_data(index)
        
        self.handler.set_augmentation()
        
        inpt=self.handler.input(self.input_path,return_profile=False)
        
        targ=self.handler.target(self.target_path,return_profile=False)
    
        targ=self._threshold_target(targ)
        
        return {
            'input': inpt, 
            'target': targ }      
        
    def select_data(self, index):
        self.index=index
        self.row=self.canopy_frame.iloc[index]
        self.input_path=self.row.imagery_path
        self.target_path=self.row.raster_path
    
    def _threshold_target(self,targ, ht_thresh = height_threshold, ndvi_thresh = ndvi_threshold):
        return ((targ[0,:,:]>ht_thresh) & (targ[1,:,:]>ndvi_thresh)).astype(np.uint8)       
    
    @classmethod
    def loader(cls,
            dataframe,
            batch_size=DEFAULT_BATCH_SIZE,
            partial_batches=False,
            loader_kwargs={},
            **kwargs):
        r""" convenience method for loading the DataLoader directly.
            
            Args:
                see class args

            Returns:
                dataloader 
        """


        return DataLoader(cls(dataframe,**kwargs),batch_size=batch_size,**loader_kwargs)

# %%
# load the dataset
train_catalog_path = '/home/ericp/UrbanTreeCanopy/taufiq/train_data_catalog.csv'

train_canopy_dataset = UrbanTreeDataset(train_catalog_path, means = means, stdevs = stdevs)

# %%
# we can access and get data with index by __getitem__(index)
train_sample = train_canopy_dataset[10]

# %% [markdown]
# ### Print min, max of each bands to ensure correct normalization

# %%
for i in range(4):
    if i == 0:
        print('red_min',train_sample['input'][i].min())
        print('red_max',train_sample['input'][i].max())
    elif i == 1:
        print('green_min',train_sample['input'][i].min())
        print('green_max',train_sample['input'][i].max())
    elif i == 2:
        print('blue_min',train_sample['input'][i].min())
        print('blue_max',train_sample['input'][i].max())
    else:
        print('nir_min',train_sample['input'][i].min())
        print('nir_max',train_sample['input'][i].max())
# Out:
# red_min -2.151465560489267
# red_max 3.239419355621189
# green_min -2.3089611089673343
# green_max 3.3443834535541814
# blue_min -2.345705034454088
# blue_max 3.5972893653079008
# nir_min -2.305223506898173
# nir_max 3.6729520798190887

# %% [markdown]
# ### Use data loader in PyTorch that will accutually read the data within batch size and put into memory.

# %%
# train_loader = DataLoader(train_canopy_dataset, batch_size=4, shuffle=True, num_workers=2)
train_loader = train_canopy_dataset.loader('/home/ericp/urban_tree_canopy/repo/datasets/train.csv')
print(type(train_loader))

# we can use dataloader as iterator by using iter() function.
train_iter = iter(train_loader)

# we can look at images and labels of batch size by extracting data .next() method.
train_loader_sample = train_iter.next()
print('input images shape on batch size = {}'.format(train_loader_sample['input'].size()))
print('target images shape on batch size = {}'.format(train_loader_sample['target'].size()))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>
# input images shape on batch size = torch.Size([16, 5, 256, 256])
# target images shape on batch size = torch.Size([16, 256, 256])

# %% [markdown]
# ### Plot the outputs from dataloader

# %%
for i in range(DEFAULT_BATCH_SIZE):    
    fig, axs=plt.subplots(1,3,figsize=(13,3))
    axs[0].imshow(train_loader_sample['input'][i][3])   
    axs[0].set_title('NIR')
    axs[1].imshow(train_loader_sample['input'][i][4])
    axs[1].set_title('NDVI')
    axs[2].imshow(train_loader_sample['target'][i])
    axs[2].set_title('Binary')
    plt.show()

# %% [markdown]
# -----------------------------------------
